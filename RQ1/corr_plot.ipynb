# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data = pd.read_csv('/Users/mingxi/Desktop/TEMP/DISS/teach_levels_data3.csv')
for i, j in enumerate(data.columns):
    print(i, j)
# Out:
# 0 Unnamed: 0
# 1 soundname
# 2 ratee
# 3 date
# 4 date2
# 5 date3
# 6 teach_topic
# 7 oect_level
# 8 final_opi_score
# 9 final_teach_score
# 10 final_teach_level
# 11 npause
# 12 nfillers
# 13 nrep
# 14 mlr
# 15 tokens_per_sec
# 16 tokens_per_sec2
# 17 words_per_sec
# 18 words_per_sec2
# 19 nsyll_per_sec_p2tk
# 20 ASD_p2tk
# 21 nsyll_per_sec2_p2tk
# 22 ASD2_p2tk
# 23 npause_per_token
# 24 nfiller_per_token
# 25 nrep_per_token
# 26 fluency_PC1
# 27 L1
# 28 L2
# 29 L3
# 30 L4
# 31 L5
# 32 L6
# 33 L7
# 34 gcp_confidence
# 35 wer3
# 36 percent_v
# 37 delta_v
# 38 varco_v
# 39 rpvi_v
# 40 npvi_v
# 41 percent_c
# 42 delta_c
# 43 varco_c
# 44 rpvi_c
# 45 npvi_c
# 46 wordtypes
# 47 swordtypes
# 48 lextypes
# 49 slextypes
# 50 wordtokens
# 51 swordtokens
# 52 lextokens
# 53 slextokens
# 54 ld
# 55 ls1
# 56 ls2
# 57 vs1
# 58 vs2
# 59 cvs1
# 60 ndw
# 61 ndwz
# 62 ndwerz
# 63 ndwesz
# 64 ttr
# 65 msttr
# 66 cttr
# 67 rttr
# 68 logttr
# 69 uber
# 70 lv
# 71 vv1
# 72 svv1
# 73 cvv1
# 74 vv2
# 75 nv
# 76 adjv
# 77 advv
# 78 modv
# 79 lca_PC1
# 80 W
# 81 S
# 82 VP
# 83 C
# 84 T
# 85 DC
# 86 CT
# 87 CP
# 88 CN
# 89 MLS
# 90 MLT
# 91 MLC
# 92 C.S
# 93 VP.T
# 94 C.T
# 95 DC.C
# 96 DC.T
# 97 T.S
# 98 CT.T
# 99 CP.T
# 100 CP.C
# 101 CN.T
# 102 CN.C
# 103 sca_PC1
# 104 topic_specific_1gram_sim
# 105 topic_specific_2gram_sim
# 106 topic_all_1gram_sim
# 107 topic_all_2gram_sim

# %%
col_li = [10]
for i in range(11,26):
    col_li.append(i)
my_data = data.iloc[:,col_li]
print(my_data.columns)
corr = my_data.corr()
# Out:
# Index(['final_teach_level', 'npause', 'nfillers', 'nrep', 'mlr',
#        'tokens_per_sec', 'tokens_per_sec2', 'words_per_sec', 'words_per_sec2',
#        'nsyll_per_sec_p2tk', 'ASD_p2tk', 'nsyll_per_sec2_p2tk', 'ASD2_p2tk',
#        'npause_per_token', 'nfiller_per_token', 'nrep_per_token'],
#       dtype='object')

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sn.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sn.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
print(corr)
# Out:
#                    final_teach_level        L1        L2        L3        L4  \
# final_teach_level           1.000000 -0.152584  0.276597  0.271179 -0.135275
# L1                         -0.152584  1.000000  0.448345  0.475420  0.966404
# L2                          0.276597  0.448345  1.000000  0.947738  0.492328
# L3                          0.271179  0.475420  0.947738  1.000000  0.519823
# L4                         -0.135275  0.966404  0.492328  0.519823  1.000000
# L5                          0.278305  0.339477  0.954002  0.904172  0.456212
# L6                          0.274413  0.465784  0.941838  0.993392  0.513157
# L7                          0.397327 -0.064055  0.838006  0.823126  0.008717
# gcp_confidence             -0.315450  0.469884  0.190581  0.141662  0.477473
# wer3                        0.132364 -0.138306  0.319283  0.311464 -0.101893
#
#                          L5        L6        L7  gcp_confidence      wer3
# final_teach_level  0.278305  0.274413  0.397327       -0.315450  0.132364
# L1                 0.339477  0.465784 -0.064055        0.469884 -0.138306
# L2                 0.954002  0.941838  0.838006        0.190581  0.319283
# L3                 0.904172  0.993392  0.823126        0.141662  0.311464
# L4                 0.456212  0.513157  0.008717        0.477473 -0.101893
# L5                 1.000000  0.903109  0.858556        0.169588  0.339033
# L6                 0.903109  1.000000  0.827985        0.136096  0.313232
# L7                 0.858556  0.827985  1.000000       -0.075219  0.443270
# gcp_confidence     0.169588  0.136096 -0.075219        1.000000 -0.071533
# wer3               0.339033  0.313232  0.443270       -0.071533  1.000000
